# %%
esm1 = """
>>> precision: 0.342 | recall: 0.184 | F1: 0.217 | AUC: 0.592 
>>> precision: 0.266 | recall: 0.171 | F1: 0.192 | AUC: 0.585
>>> precision: 0.365 | recall: 0.191 | F1: 0.222 | AUC: 0.595 
>>> precision: 0.365 | recall: 0.197 | F1: 0.227 | AUC: 0.599 
>>> precision: 0.354 | recall: 0.204 | F1: 0.234 | AUC: 0.602 
>>> precision: 0.334 | recall: 0.243 | F1: 0.269 | AUC: 0.621 
>>> precision: 0.344 | recall: 0.271 | F1: 0.287 | AUC: 0.634 
>>> precision: 0.344 | recall: 0.271 | F1: 0.287 | AUC: 0.634 
>>> precision: 0.342 | recall: 0.276 | F1: 0.291 | AUC: 0.637
>>> precision: 0.354 | recall: 0.271 | F1: 0.284 | AUC: 0.634 
>>> precision: 0.351 | recall: 0.263 | F1: 0.28  | AUC: 0.631 
>>> precision: 0.357 | recall: 0.271 | F1: 0.286 | AUC: 0.634 
>>> precision: 0.354 | recall: 0.271 | F1: 0.284 | AUC: 0.634 
>>> precision: 0.351 | recall: 0.263 | F1: 0.28  | AUC: 0.631 
>>> precision: 0.351 | recall: 0.263 | F1: 0.28  | AUC: 0.631 
>>> precision: 0.331 | recall: 0.263 | F1: 0.278 | AUC: 0.631 
>>> precision: 0.354 | recall: 0.263 | F1: 0.282 | AUC: 0.631 
>>> precision: 0.361 | recall: 0.271 | F1: 0.289 | AUC: 0.634 
"""

# %%
import matplotlib.pyplot as plt
with open("layer_12_attention_1.out") as f:
    result_35m = f.readlines()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_30267/696857571.py in <module>
#       1 import matplotlib.pyplot as plt
# ----> 2 with open("layer_12_attention_1.out") as f:
#       3     result_35m = f.readlines()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'layer_12_attention_1.out'

# %%
import matplotlib.pyplot as plt
with open("layer_12_attention_1.out") as f:
    result_35m = f.readlines()
result_35m_precisions = []
result_35m_recalls = []
result_35m_F1s = []
result_35m_AUCs = []
for line in result_35m:
    if line.startswith(">>> pre"):
        result_35m_precisions.append(float(line.split("precision: ")[1].split("|")[0]))
        result_35m_recalls.append(float(line.split("recall: ")[1].split("|")[0]))
        result_35m_F1s.append(float(line.split("F1: ")[1].split("|")[0]))
        result_35m_AUCs.append(float(line.split("AUC: ")[1]))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_128370/2116046292.py in <module>
#       1 import matplotlib.pyplot as plt
# ----> 2 with open("layer_12_attention_1.out") as f:
#       3     result_35m = f.readlines()
#       4 result_35m_precisions = []
#       5 result_35m_recalls = []
#
# FileNotFoundError: [Errno 2] No such file or directory: 'layer_12_attention_1.out'

# %%
import matplotlib.pyplot as plt
with open("layer_12_attention_1_top_k.out") as f:
    result_35m_2 = f.readlines()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_128370/1894230293.py in <module>
#       1 import matplotlib.pyplot as plt
# ----> 2 with open("layer_12_attention_1_top_k.out") as f:
#       3     result_35m_2 = f.readlines()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'layer_12_attention_1_top_k.out'

# %%
result_35m_2_precisions = []
result_35m_2_recalls = []
result_35m_2_F1s = []
result_35m_2_AUCs = []
for line in result_35m_2:
    if line.startswith(">>> pre"):
        result_35m_2_precisions.append(float(line.split("precision: ")[1].split("|")[0]))
        result_35m_2_recalls.append(float(line.split("recall: ")[1].split("|")[0]))
        result_35m_2_F1s.append(float(line.split("F1: ")[1].split("|")[0]))
        result_35m_2_AUCs.append(float(line.split("AUC: ")[1]))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_128370/2125792018.py in <module>
#       3 result_35m_2_F1s = []
#       4 result_35m_2_AUCs = []
# ----> 5 for line in result_35m_2:
#       6     if line.startswith(">>> pre"):
#       7         result_35m_2_precisions.append(float(line.split("precision: ")[1].split("|")[0]))
#
# NameError: name 'result_35m_2' is not defined

# %%
import matplotlib.pyplot as plt
with open("layer_12_attention_1_top_k_sum.out") as f:
    result_35m_3 = f.readlines()
result_35m_3_precisions = []
result_35m_3_recalls = []
result_35m_3_F1s = []
result_35m_3_AUCs = []
for line in result_35m_3:
    if line.startswith(">>> pre"):
        result_35m_3_precisions.append(float(line.split("precision: ")[1].split("|")[0]))
        result_35m_3_recalls.append(float(line.split("recall: ")[1].split("|")[0]))
        result_35m_3_F1s.append(float(line.split("F1: ")[1].split("|")[0]))
        result_35m_3_AUCs.append(float(line.split("AUC: ")[1]))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_128370/1870762549.py in <module>
#       1 import matplotlib.pyplot as plt
# ----> 2 with open("layer_12_attention_1_top_k_sum.out") as f:
#       3     result_35m_3 = f.readlines()
#       4 result_35m_3_precisions = []
#       5 result_35m_3_recalls = []
#
# FileNotFoundError: [Errno 2] No such file or directory: 'layer_12_attention_1_top_k_sum.out'

# %%
import matplotlib.pyplot as plt
with open("layer_12_attention_1_learnable_k.out") as f:
    result_35m_4 = f.readlines()
result_35m_4_precisions = []
result_35m_4_recalls = []
result_35m_4_F1s = []
result_35m_4_AUCs = []
for line in result_35m_4:
    if line.startswith(">>> pre"):
        result_35m_4_precisions.append(float(line.split("precision: ")[1].split("|")[0]))
        result_35m_4_recalls.append(float(line.split("recall: ")[1].split("|")[0]))
        result_35m_4_F1s.append(float(line.split("F1: ")[1].split("|")[0]))
        result_35m_4_AUCs.append(float(line.split("AUC: ")[1]))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_128370/3071329520.py in <module>
#       1 import matplotlib.pyplot as plt
# ----> 2 with open("layer_12_attention_1_learnable_k.out") as f:
#       3     result_35m_4 = f.readlines()
#       4 result_35m_4_precisions = []
#       5 result_35m_4_recalls = []
#
# FileNotFoundError: [Errno 2] No such file or directory: 'layer_12_attention_1_learnable_k.out'

# %%
import matplotlib.pyplot as plt
with open("layer_30_attention_1.out") as f:
    result_150m = f.readlines()

# %%
result_150m_precisions = []
result_150m_recalls = []
result_150m_F1s = []
result_150m_AUCs = []
for line in result_150m:
    if line.startswith(">>> pre"):
        result_150m_precisions.append(float(line.split("precision: ")[1].split("|")[0]))
        result_150m_recalls.append(float(line.split("recall: ")[1].split("|")[0]))
        result_150m_F1s.append(float(line.split("F1: ")[1].split("|")[0]))
        result_150m_AUCs.append(float(line.split("AUC: ")[1]))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_128370/2449764695.py in <module>
#       3 result_150m_F1s = []
#       4 result_150m_AUCs = []
# ----> 5 for line in result_150m:
#       6     if line.startswith(">>> pre"):
#       7         result_150m_precisions.append(float(line.split("precision: ")[1].split("|")[0]))
#
# NameError: name 'result_150m' is not defined

# %%
import matplotlib.pyplot as plt
with open("layer_30.out") as f:
    result_150m = f.readlines()

result_150m_precisions = []
result_150m_recalls = []
result_150m_F1s = []
result_150m_AUCs = []
for line in result_150m:
    if line.startswith("pre"):
        result_150m_precisions.append(float(line.split("precision: ")[1].split("|")[0]))
        result_150m_recalls.append(float(line.split("recall: ")[1].split("|")[0]))
        result_150m_F1s.append(float(line.split("F1: ")[1].split("|")[0]))
        result_150m_AUCs.append(float(line.split("AUC: ")[1]))

# %%
import matplotlib.pyplot as plt
with open("650m.out") as f:
    result_650m = f.readlines()

result_650m = esm1.split("\n")
result_650m_precisions = []
result_650m_recalls = []
result_650m_F1s = []
result_650m_AUCs = []
for line in result_650m:
    if line.startswith("pre"):
        result_650m_precisions.append(float(line.split("precision: ")[1].split("|")[0]))
        result_650m_recalls.append(float(line.split("recall: ")[1].split("|")[0]))
        result_650m_F1s.append(float(line.split("F1: ")[1].split("|")[0]))
        result_650m_AUCs.append(float(line.split("AUC: ")[1]))

# %%
result_650m
# Out:
# ['',
#  'precision: 0.342 | recall: 0.184 | Fl: 0.217 | AUC: 0.592 ',
#  'precision: 0.266 | recall: 0.171 | F1: 0.192 | AUC: 0.585',
#  'precision: 0.365 | recall: 0.191 | F1: 0.222 | AUC: 0.595 ',
#  'precision: 0.365 | recall: 0.197 | F1: 0.227 | AUC: 0.599 ',
#  'precision: 0.354 | recall: 0.204 | F1: 0.234 | AUC: 0.602 ',
#  'precision: 0.334 | recall: 0.243 | F1: 0.269 | AUC: 0.621 ',
#  'precision: 0.344 | recall: 0.271 | F1: 0.287 | AUC: 0.634 ',
#  'precision: 0.344 | recall: 0.271 | F1: 0.287 | AUC: 0.634 ',
#  'precision: 0.342 | recall: 0.276 | F1: 0.291 | AUC: 0.637',
#  'precision: 0.354 | recall: 0.271 | F1: 0.284 | AUC: 0.634 ',
#  'precision: 0.351 | recall: 0.263 | F1: 0.28  | AUC: 0.631 ',
#  'precision: 0.357 | recall: 0.271 | F1: 0.286 | AUC: 0.634 ',
#  'precision: 0.354 | recall: 0.271 | F1: 0.284 | AUC: 0.634 ',
#  'precision: 0.351 | recall: 0.263 | F1: 0.28  | AUC: 0.631 ',
#  'precision: 0.351 | recall: 0.263 | F1: 0.28  | AUC: 0.631 ',
# ...

# %%
len(result_650m_F1s)
# Out:
# 18

# %%
plt.plot(range(50, 1000, 50), result_35m_AUCs[-19:], label='esm2 35M')
plt.plot(range(50, 950, 50), result_650m_AUCs[-19:], label='esm1 650M')
plt.legend()
plt.title("AUC")
# Out:
# Text(0.5, 1.0, 'AUC')

# %%
plt.plot(range(50, 1000, 50), result_35m_recalls[-19:], label='esm2 35M')
plt.plot(range(50, 1000, 50), result_150m_recalls[-19:], label='esm2 150M')
# plt.plot(range(50, 1000, 50), result_650m_recalls[-19:], label='esm1 650M')
plt.legend()
plt.title("Recall")
# Out:
# Text(0.5, 1.0, 'Recall')

# %%
plt.plot(range(50, 1000, 50), result_35m_F1s[-19:], label='esm2 35M')
plt.plot(range(50, 1000, 50), result_150m_F1s[-19:], label='esm2 150M')
# plt.plot(range(50, 1000, 50), result_650m_F1s[-19:], label='esm1 650M')
plt.legend()
plt.title("F1")
# Out:
# Text(0.5, 1.0, 'F1')

# %%
plt.plot(range(50, 1000, 50), result_35m_AUCs[-19:], label='esm2 35M')
plt.plot(range(50, 1000, 50), result_150m_AUCs[-19:], label='esm2 150M')
# plt.plot(range(50, 1000, 50), result_650m_AUCs[-19:], label='esm1 650M')
plt.legend()
plt.title("AUC")
# Out:
# Text(0.5, 1.0, 'AUC')

# %%
import matplotlib.pyplot as plt
with open("layer_12_attention_1_use_input_as_k.out") as f:
    result_35m_5 = f.readlines()
result_35m_5_precisions = []
result_35m_5_recalls = []
result_35m_5_F1s = []
result_35m_5_AUCs = []
for line in result_35m_5:
    if line.startswith(">>> pre"):
        result_35m_5_precisions.append(float(line.split("precision: ")[1].split("|")[0]))
        result_35m_5_recalls.append(float(line.split("recall: ")[1].split("|")[0]))
        result_35m_5_F1s.append(float(line.split("F1: ")[1].split("|")[0]))
        result_35m_5_AUCs.append(float(line.split("AUC: ")[1]))

# %%
plt.plot(range(50, 1000, 50), result_35m_precisions[-19:], label='Design 1')
plt.plot(range(50, 1000, 50), result_35m_2_precisions[-19:], label='Design 2')
plt.plot(range(50, 1000, 50), result_35m_3_precisions[-19:], label='Design 3')
plt.plot(range(50, 1000, 50), result_35m_4_precisions[-19:], label='Design 4')
plt.plot(range(50, 1000, 50), result_35m_5_precisions[-19:], label='Design 5')
plt.plot(range(50, 1000, 50), [0.34] * 19, label='Baseline')
plt.plot()
plt.legend()
plt.title("Precision")
# Out:
# Text(0.5, 1.0, 'Precision')

# %%
plt.plot(range(50, 1000, 50), result_35m_recalls[-19:], label='Design 1')
plt.plot(range(50, 1000, 50), result_35m_2_recalls[-19:], label='Design 2')
plt.plot(range(50, 1000, 50), result_35m_3_recalls[-19:], label='Design 3')
plt.plot(range(50, 1000, 50), result_35m_4_recalls[-19:], label='Design 4')
plt.plot(range(50, 1000, 50), result_35m_5_recalls[-19:], label='Design 5')
plt.plot(range(50, 1000, 50), [0.20] * 19, label='Baseline')

plt.legend()
plt.title("Recall")
# Out:
# Text(0.5, 1.0, 'Recall')

# %%
plt.plot(range(50, 1000, 50), result_35m_F1s[-19:], label='Design 1')
plt.plot(range(50, 1000, 50), result_35m_2_F1s[-19:], label='Design 2')
plt.plot(range(50, 1000, 50), result_35m_3_F1s[-19:], label='Design 3')
plt.plot(range(50, 1000, 50), result_35m_4_F1s[-19:], label='Design 4')
plt.plot(range(50, 1000, 50), result_35m_5_F1s[-19:], label='Design 5')
plt.plot(range(50, 1000, 50), [0.22] * 19, label='Baseline')

plt.legend()
plt.title("F1")
# Out:
# Text(0.5, 1.0, 'F1')

# %%
plt.plot(range(50, 1000, 50), result_35m_AUCs[-19:], label='Design 1')
plt.plot(range(50, 1000, 50), result_35m_2_AUCs[-19:], label='Design 2')
plt.plot(range(50, 1000, 50), result_35m_3_AUCs[-19:], label='Design 3')
plt.plot(range(50, 1000, 50), result_35m_4_AUCs[-19:], label='Design 4')
plt.plot(range(50, 1000, 50), result_35m_5_AUCs[-19:], label='Design 5')
plt.plot(range(50, 1000, 50), [0.60] * 19, label='Baseline')

plt.legend()
plt.title("AUC")
# Out:
# Text(0.5, 1.0, 'AUC')

# %%
import matplotlib.pyplot as plt
with open("nohup.out") as f:
    result_35m_fix_backbone = f.readlines()
result_35m_fix_backbone_precisions = []
result_35m_fix_backbone_recalls = []
result_35m_fix_backbone_F1s = []
result_35m_fix_backbone_AUCs = []
for line in result_35m_fix_backbone:
    if line.startswith(">>> pre"):
        result_35m_fix_backbone_precisions.append(float(line.split("precision: ")[1].split("|")[0]))
        result_35m_fix_backbone_recalls.append(float(line.split("recall: ")[1].split("|")[0]))
        result_35m_fix_backbone_F1s.append(float(line.split("F1: ")[1].split("|")[0]))
        result_35m_fix_backbone_AUCs.append(float(line.split("AUC: ")[1]))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_128370/3126952282.py in <module>
#       1 import matplotlib.pyplot as plt
# ----> 2 with open("nohup.out") as f:
#       3     result_35m_fix_backbone = f.readlines()
#       4 result_35m_fix_backbone_precisions = []
#       5 result_35m_fix_backbone_recalls = []
#
# FileNotFoundError: [Errno 2] No such file or directory: 'nohup.out'

# %%
backbone_tuning = """
>>> precision: 0.345 | recall: 0.197| F1: 0.232 | AUC: 0.599 
>>> precision: 0.304 | recall: 0.204| F1: 0.226 | AUC: 0.602 
>>> precision: 0.274 | recall: 0.197| F1: 0.21 | AUC: 0.598 
>>> precision: 0.257 | recall: 0.151| F1: 0.177 | AUC: 0.575 
>>> precision: 0.283 | recall: 0.171| F1: 0.2 | AUC: 0.585 
>>> precision: 0.249 | recall: 0.178| F1: 0.197 | AUC: 0.588 
>>> precision: 0.201 | recall: 0.151| F1: 0.162 | AUC: 0.575 
>>> precision: 0.338 | recall: 0.191| F1: 0.226 | AUC: 0.595 
>>> precision: 0.347 | recall: 0.204| F1: 0.231 | AUC: 0.602 
>>> precision: 0.286 | recall: 0.191| F1: 0.211 | AUC: 0.595 
>>> precision: 0.26 | recall: 0.184| F1: 0.203 | AUC: 0.592 
>>> precision: 0.352 | recall: 0.184| F1: 0.218 | AUC: 0.592 
>>> precision: 0.342 | recall: 0.178| F1: 0.207 | AUC: 0.589
"""

# %%
backbone_tuning_attention = """
>>> precision: 0.259 | recall: 0.178| F1: 0.192 | AUC: 0.589 
>>> precision: 0.26 | recall: 0.211| F1: 0.221 | AUC: 0.605 
>>> precision: 0.234 | recall: 0.178| F1: 0.193 | AUC: 0.589 
>>> precision: 0.285 | recall: 0.184| F1: 0.201 | AUC: 0.592 
>>> precision: 0.258 | recall: 0.171| F1: 0.184 | AUC: 0.585 
>>> precision: 0.294 | recall: 0.191| F1: 0.205 | AUC: 0.594 
>>> precision: 0.25 | recall: 0.171| F1: 0.19 | AUC: 0.586 
>>> precision: 0.232 | recall: 0.171| F1: 0.186 | AUC: 0.585 
>>> precision: 0.344 | recall: 0.23| F1: 0.243 | AUC: 0.614 
>>> precision: 0.321 | recall: 0.171| F1: 0.188 | AUC: 0.585 
>>> precision: 0.264 | recall: 0.158| F1: 0.176 | AUC: 0.579 
>>> precision: 0.341 | recall: 0.178| F1: 0.208 | AUC: 0.589 
"""

# %%
result_35m_backbone_tuning_design1 = backbone_tuning_attention.split("\n")

# %%
result_35m_backbone_tuning = backbone_tuning.split("\n")

# %%
result_35m_fix_backbone_precisions = []
result_35m_fix_backbone_recalls = []
result_35m_fix_backbone_F1s = []
result_35m_fix_backbone_AUCs = []
for line in result_35m_fix_backbone:
    if line.startswith(">>> pre"):
        result_35m_fix_backbone_precisions.append(float(line.split("precision: ")[1].split("|")[0]))
        result_35m_fix_backbone_recalls.append(float(line.split("recall: ")[1].split("|")[0]))
        result_35m_fix_backbone_F1s.append(float(line.split("F1: ")[1].split("|")[0]))
        result_35m_fix_backbone_AUCs.append(float(line.split("AUC: ")[1]))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_128370/1839350300.py in <module>
#       3 result_35m_fix_backbone_F1s = []
#       4 result_35m_fix_backbone_AUCs = []
# ----> 5 for line in result_35m_fix_backbone:
#       6     if line.startswith(">>> pre"):
#       7         result_35m_fix_backbone_precisions.append(float(line.split("precision: ")[1].split("|")[0]))
#
# NameError: name 'result_35m_fix_backbone' is not defined

# %%
result_35m_backbone_tuning_design1_precisions = []
result_35m_backbone_tuning_design1_recalls = []
result_35m_backbone_tuning_design1_F1s = []
result_35m_backbone_tuning_design1_AUCs = []
for line in result_35m_backbone_tuning_design1:
    if line.startswith("pre"):
        result_35m_backbone_tuning_design1_precisions.append(float(line.split("precision: ")[1].split("|")[0]))
        result_35m_backbone_tuning_design1_recalls.append(float(line.split("recall: ")[1].split("|")[0]))
        result_35m_backbone_tuning_design1_F1s.append(float(line.split("F1: ")[1].split("|")[0]))
        result_35m_backbone_tuning_design1_AUCs.append(float(line.split("AUC: ")[1]))

# %%
result_35m_backbone_tuning_precisions = []
result_35m_backbone_tuning_recalls = []
result_35m_backbone_tuning_F1s = []
result_35m_backbone_tuning_AUCs = []
for line in result_35m_backbone_tuning:
    if line.startswith("pre"):
        result_35m_backbone_tuning_precisions.append(float(line.split("precision: ")[1].split("|")[0]))
        result_35m_backbone_tuning_recalls.append(float(line.split("recall: ")[1].split("|")[0]))
        result_35m_backbone_tuning_F1s.append(float(line.split("F1: ")[1].split("|")[0]))
        result_35m_backbone_tuning_AUCs.append(float(line.split("AUC: ")[1]))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_44873/537741513.py in <module>
#       3 result_35m_backbone_tuning_F1s = []
#       4 result_35m_backbone_tuning_AUCs = []
# ----> 5 for line in result_35m_backbone_tuning:
#       6     if line.startswith("pre"):
#       7         result_35m_backbone_tuning_precisions.append(float(line.split("precision: ")[1].split("|")[0]))
#
# NameError: name 'result_35m_backbone_tuning' is not defined

# %%
plt.plot(range(50, 1000, 50), result_35m_fix_backbone_AUCs[-19:], label='ESM2 35M')
plt.plot(list(range(50, 650, 50)) + [950], result_35m_backbone_tuning_AUCs[-19:], label='ESM2 35M + Backbone Tuning')
plt.legend()
plt.title("AUC")
# Out:
# Text(0.5, 1.0, 'AUC')

# %%
plt.plot(range(50, 1000, 50), result_35m_fix_backbone_recalls[-19:], label='ESM2 35M')
plt.plot(list(range(50, 650, 50)) + [950], result_35m_backbone_tuning_recalls[-19:], label='ESM2 35M + Backbone Tuning')
plt.legend()
plt.title("AUC")

# %%
import matplotlib.pyplot as plt
with open("layer_12_attention_1_input_as_k.out") as f:
    result_35m_5 = f.readlines()
result_35m_5_precisions = []
result_35m_5_recalls = []
result_35m_5_F1s = []
result_35m_5_AUCs = []
for line in result_35m_5:
    if line.startswith(">>> pre"):
        result_35m_5_precisions.append(float(line.split("precision: ")[1].split("|")[0]))
        result_35m_5_recalls.append(float(line.split("recall: ")[1].split("|")[0]))
        result_35m_5_F1s.append(float(line.split("F1: ")[1].split("|")[0]))
        result_35m_5_AUCs.append(float(line.split("AUC: ")[1]))

# %%
plt.plot(range(50, 1000, 50), result_35m_AUCs[-19:], label='Design 1')
plt.plot(range(50, 1000, 50), result_35m_5_AUCs[-19:], label='Design 5')
plt.legend()
plt.title("AUC")
# Out:
# Text(0.5, 1.0, 'AUC')

# %%
import matplotlib.pyplot as plt
with open("nohup.out") as f:
    result_35m_fix_backbone = f.readlines()
result_35m_fix_backbone_precisions = []
result_35m_fix_backbone_recalls = []
result_35m_fix_backbone_F1s = []
result_35m_fix_backbone_AUCs = []
for line in result_35m_fix_backbone:
    if line.startswith(">>> pre"):
        result_35m_fix_backbone_precisions.append(float(line.split("precision: ")[1].split("|")[0]))
        result_35m_fix_backbone_recalls.append(float(line.split("recall: ")[1].split("|")[0]))
        result_35m_fix_backbone_F1s.append(float(line.split("F1: ")[1].split("|")[0]))
        result_35m_fix_backbone_AUCs.append(float(line.split("AUC: ")[1]))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_44873/3126952282.py in <module>
#       1 import matplotlib.pyplot as plt
# ----> 2 with open("nohup.out") as f:
#       3     result_35m_fix_backbone = f.readlines()
#       4 result_35m_fix_backbone_precisions = []
#       5 result_35m_fix_backbone_recalls = []
#
# FileNotFoundError: [Errno 2] No such file or directory: 'nohup.out'

# %%
plt.plot(range(50, 1000, 50), result_35m_fix_backbone_AUCs[-19:], label='ESM2 35M')
plt.plot(list(range(50, 650, 50)) + [950], result_35m_backbone_tuning_AUCs[-19:], label='ESM2 35M + Backbone Tuning')
plt.plot(range(50, 1000, 50), result_35m_AUCs[-19:], label='Design 1')
plt.plot(list(range(50, 600, 50)) + [950], result_35m_backbone_tuning_design1_AUCs[-19:], label='Design 1 + Backbone Tuning')
plt.legend()
plt.title("AUC")
# Out:
# Text(0.5, 1.0, 'AUC')

# %%
import matplotlib.pyplot as plt
with open("layer_12_attention_1-cls.out") as f:
    result_35m_1_cls = f.readlines()
result_35m_1_cls_precisions = []
result_35m_1_cls_recalls = []
result_35m_1_cls_F1s = []
result_35m_1_cls_AUCs = []
for line in result_35m_1_cls:
    if line.startswith(">>> pre"):
        result_35m_1_cls_precisions.append(float(line.split("precision: ")[1].split("|")[0]))
        result_35m_1_cls_recalls.append(float(line.split("recall: ")[1].split("|")[0]))
        result_35m_1_cls_F1s.append(float(line.split("F1: ")[1].split("|")[0]))
        result_35m_1_cls_AUCs.append(float(line.split("AUC: ")[1]))

# %%
plt.plot(range(50, 1000, 50), result_35m_AUCs[-19:], label='Design 1')
plt.plot(range(50, 1000, 50), result_35m_1_cls_AUCs[-19:], label='Design 1 + CLS loss')
plt.legend()
plt.title("AUC")
# Out:
# Text(0.5, 1.0, 'AUC')

# %%
import matplotlib.pyplot as plt
with open("layer_12_attention_1-weighted.out") as f:
    result_35m_1_linear = f.readlines()
result_35m_1_linear_precisions = []
result_35m_1_linear_recalls = []
result_35m_1_linear_F1s = []
result_35m_1_linear_AUCs = []
for line in result_35m_1_linear:
    if line.startswith(">>> pre"):
        result_35m_1_linear_precisions.append(float(line.split("precision: ")[1].split("|")[0]))
        result_35m_1_linear_recalls.append(float(line.split("recall: ")[1].split("|")[0]))
        result_35m_1_linear_F1s.append(float(line.split("F1: ")[1].split("|")[0]))
        result_35m_1_linear_AUCs.append(float(line.split("AUC: ")[1]))

# %%
print(len(result_35m_1_linear_precisions))
# Out:
# 9

# %%
plt.plot(range(50, 1000, 50), result_35m_AUCs[-19:], label='Design 1')
plt.plot(range(50, 500, 50), result_35m_1_linear_AUCs[-19:], label='Design 1 + linear loss penalty')
plt.legend()
plt.title("AUC")
# Out:
# Text(0.5, 1.0, 'AUC')

# %%
import matplotlib.pyplot as plt
with open("lora.out") as f:
    lora = f.readlines()
lora_precisions = []
lora_recalls = []
lora_F1s = []
lora_AUCs = []
for line in lora:
    if line.startswith(">>> pre"):
        lora_precisions.append(float(line.split("precision: ")[1].split("|")[0]))
        lora_recalls.append(float(line.split("recall: ")[1].split("|")[0]))
        lora_F1s.append(float(line.split("F1: ")[1].split("|")[0]))
        lora_AUCs.append(float(line.split("AUC: ")[1]))

# %%
import matplotlib.pyplot as plt
with open("baseline.out") as f:
    baseline = f.readlines()
baseline_precisions = []
baseline_recalls = []
baseline_F1s = []
baseline_AUCs = []
for line in baseline:
    if line.startswith(">>> pre"):
        baseline_precisions.append(float(line.split("precision: ")[1].split("|")[0]))
        baseline_recalls.append(float(line.split("recall: ")[1].split("|")[0]))
        baseline_F1s.append(float(line.split("F1: ")[1].split("|")[0]))
        baseline_AUCs.append(float(line.split("AUC: ")[1]))

# %%
plt.plot(range(50, 1000, 50), baseline_F1s[-19:], label='ESM2 35M')
plt.plot(list(range(50, 650, 50)) + [950], result_35m_backbone_tuning_F1s[-19:], label='ESM2 35M + Backbone Tuning')
plt.plot(list(range(50, 1000, 50)), lora_F1s[-19:], label='ESM2 35M + LoRA (rank=8)')
plt.legend()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_44873/2254943883.py in <module>
#       1 plt.plot(range(50, 1000, 50), baseline_F1s[-19:], label='ESM2 35M')
# ----> 2 plt.plot(list(range(50, 650, 50)) + [950], result_35m_backbone_tuning_F1s[-19:], label='ESM2 35M + Backbone Tuning')
#       3 plt.plot(list(range(50, 1000, 50)), lora_F1s[-19:], label='ESM2 35M + LoRA (rank=8)')
#       4 plt.legend()
#
# NameError: name 'result_35m_backbone_tuning_F1s' is not defined

# %%
import matplotlib.pyplot as plt
with open("lora_rank_32.out") as f:
    lora = f.readlines()
lora_rank_32_precisions = []
lora_rank_32_recalls = []
lora_rank_32_F1s = []
lora_rank_32_AUCs = []
for line in lora:
    if line.startswith(">>> pre"):
        lora_rank_32_precisions.append(float(line.split("precision: ")[1].split("|")[0]))
        lora_rank_32_recalls.append(float(line.split("recall: ")[1].split("|")[0]))
        lora_rank_32_F1s.append(float(line.split("F1: ")[1].split("|")[0]))
        lora_rank_32_AUCs.append(float(line.split("AUC: ")[1]))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_4054765/587893053.py in <module>
#       1 import matplotlib.pyplot as plt
# ----> 2 with open("lora_rank_32.out") as f:
#       3     lora = f.readlines()
#       4 lora_rank_32_precisions = []
#       5 lora_rank_32_recalls = []
#
# FileNotFoundError: [Errno 2] No such file or directory: 'lora_rank_32.out'

# %%
plt.figure(figsize=(10, 10))
plt.subplot(2, 2, 1)
plt.plot(range(50, 1000, 50), baseline_precisions[-19:], label='ESM2 35M')
plt.plot(list(range(50, 600, 50)) + [950], result_35m_backbone_tuning_design1_precisions[-19:], label='ESM2 35M + Backbone Tuning')
plt.plot(list(range(50, 1000, 50)), lora_precisions[-19:], label='ESM2 35M + LoRA (rank=8)')
plt.plot(list(range(50, 1000, 50)), lora_rank_32_precisions[-19:], label='ESM2 35M + LoRA (rank=32)')
plt.legend()
plt.title("Precisions")
plt.subplot(2, 2, 2)
plt.plot(range(50, 1000, 50), baseline_recalls[-19:], label='ESM2 35M')
plt.plot(list(range(50, 600, 50)) + [950], result_35m_backbone_tuning_design1_recalls[-19:], label='ESM2 35M + Backbone Tuning')
plt.plot(list(range(50, 1000, 50)), lora_recalls[-19:], label='ESM2 35M + LoRA (rank=8)')
plt.plot(list(range(50, 1000, 50)), lora_rank_32_recalls[-19:], label='ESM2 35M + LoRA (rank=32)')
plt.legend()
plt.title("Recalls")
plt.subplot(2, 2, 3)
plt.plot(range(50, 1000, 50), baseline_F1s[-19:], label='ESM2 35M')
plt.plot(list(range(50, 600, 50)) + [950], result_35m_backbone_tuning_design1_F1s[-19:], label='ESM2 35M + Backbone Tuning')
plt.plot(list(range(50, 1000, 50)), lora_F1s[-19:], label='ESM2 35M + LoRA (rank=8)')
plt.plot(list(range(50, 1000, 50)), lora_rank_32_F1s[-19:], label='ESM2 35M + LoRA (rank=32)')
plt.legend()
plt.title("F1")
plt.subplot(2, 2, 4)
plt.plot(range(50, 1000, 50), baseline_AUCs[-19:], label='ESM2 35M')
plt.plot(list(range(50, 600, 50)) + [950], result_35m_backbone_tuning_design1_AUCs[-19:], label='ESM2 35M + Backbone Tuning')
plt.plot(list(range(50, 1000, 50)), lora_AUCs[-19:], label='ESM2 35M + LoRA (rank=8)')
plt.plot(list(range(50, 1000, 50)), lora_rank_32_AUCs[-19:], label='ESM2 35M + LoRA (rank=32)')
plt.legend()
plt.title("AUC")
# Out:
# Text(0.5, 1.0, 'AUC')

# %%
import matplotlib.pyplot as plt
with open("lora_ranking_1e-3.out") as f:
    lora = f.readlines()
lora_rank_1e_3_5e_4_precisions = []
lora_rank_1e_3_5e_4_recalls = []
lora_rank_1e_3_5e_4_F1s = []
lora_rank_1e_3_5e_4_AUCs = []
for line in lora:
    if line.startswith(">>> pre"):
        lora_rank_1e_3_5e_4_precisions.append(float(line.split("precision: ")[1].split("|")[0]))
        lora_rank_1e_3_5e_4_recalls.append(float(line.split("recall: ")[1].split("|")[0]))
        lora_rank_1e_3_5e_4_F1s.append(float(line.split("F1: ")[1].split("|")[0]))
        lora_rank_1e_3_5e_4_AUCs.append(float(line.split("AUC: ")[1]))

# %%
import matplotlib.pyplot as plt
with open("lora_ranking_1e-3_1e-4.out") as f:
    lora = f.readlines()
lora_rank_1e_3_1e_4_precisions = []
lora_rank_1e_3_1e_4_recalls = []
lora_rank_1e_3_1e_4_F1s = []
lora_rank_1e_3_1e_4_AUCs = []
for line in lora:
    if line.startswith(">>> pre"):
        lora_rank_1e_3_1e_4_precisions.append(float(line.split("precision: ")[1].split("|")[0]))
        lora_rank_1e_3_1e_4_recalls.append(float(line.split("recall: ")[1].split("|")[0]))
        lora_rank_1e_3_1e_4_F1s.append(float(line.split("F1: ")[1].split("|")[0]))
        lora_rank_1e_3_1e_4_AUCs.append(float(line.split("AUC: ")[1]))

# %%
import matplotlib.pyplot as plt
with open("lora_ranking_1e-3_1e-5.out") as f:
    lora = f.readlines()
lora_rank_1e_3_1e_5_precisions = []
lora_rank_1e_3_1e_5_recalls = []
lora_rank_1e_3_1e_5_F1s = []
lora_rank_1e_3_1e_5_AUCs = []
for line in lora:
    if line.startswith(">>> pre"):
        lora_rank_1e_3_1e_5_precisions.append(float(line.split("precision: ")[1].split("|")[0]))
        lora_rank_1e_3_1e_5_recalls.append(float(line.split("recall: ")[1].split("|")[0]))
        lora_rank_1e_3_1e_5_F1s.append(float(line.split("F1: ")[1].split("|")[0]))
        lora_rank_1e_3_1e_5_AUCs.append(float(line.split("AUC: ")[1]))

# %%
import matplotlib.pyplot as plt
with open("lora_ranking_1e-3_5e-5.out") as f:
    lora = f.readlines()
lora_rank_1e_3_5e_5_precisions = []
lora_rank_1e_3_5e_5_recalls = []
lora_rank_1e_3_5e_5_F1s = []
lora_rank_1e_3_5e_5_AUCs = []
for line in lora:
    if line.startswith(">>> pre"):
        lora_rank_1e_3_5e_5_precisions.append(float(line.split("precision: ")[1].split("|")[0]))
        lora_rank_1e_3_5e_5_recalls.append(float(line.split("recall: ")[1].split("|")[0]))
        lora_rank_1e_3_5e_5_F1s.append(float(line.split("F1: ")[1].split("|")[0]))
        lora_rank_1e_3_5e_5_AUCs.append(float(line.split("AUC: ")[1]))

# %%
plt.figure(figsize=(10, 10))
plt.subplot(2, 2, 1)
plt.plot(range(10, 110, 10), lora_rank_1e_3_5e_4_precisions, label='ESM2 35M,r8,lr_esm_5e-4,lr_1e-3')
plt.plot(range(10, 110, 10), lora_rank_1e_3_1e_4_precisions, label='ESM2 35M,r8,lr_esm_1e-4,lr_1e-3')
plt.plot(range(10, 110, 10), lora_rank_1e_3_1e_5_precisions, label='ESM2 35M,r8,lr_esm_1e-5,lr_1e-3')
plt.plot(range(10, 110, 10), lora_rank_1e_3_5e_5_precisions, label='ESM2 35M,r8,lr_esm_5e-5,lr_1e-3')
plt.legend()
plt.title("Precisions")
plt.subplot(2, 2, 2)
plt.plot(range(10, 110, 10), lora_rank_1e_3_5e_4_recalls, label='ESM2 35M,r8,lr_esm_5e-4,lr_1e-3')
plt.plot(range(10, 110, 10), lora_rank_1e_3_1e_4_recalls, label='ESM2 35M,r8,lr_esm_1e-4,lr_1e-3')
plt.plot(range(10, 110, 10), lora_rank_1e_3_1e_5_recalls, label='ESM2 35M,r8,lr_esm_1e-5,lr_1e-3')
plt.plot(range(10, 110, 10), lora_rank_1e_3_5e_5_recalls, label='ESM2 35M,r8,lr_esm_5e-5,lr_1e-3')
plt.legend()
plt.title("Recalls")
plt.subplot(2, 2, 3)
plt.plot(range(10, 110, 10), lora_rank_1e_3_5e_4_F1s, label='ESM2 35M,r8,lr_esm_5e-4,lr_1e-3')
plt.plot(range(10, 110, 10), lora_rank_1e_3_1e_4_F1s, label='ESM2 35M,r8,lr_esm_1e-4,lr_1e-3')
plt.plot(range(10, 110, 10), lora_rank_1e_3_1e_5_F1s, label='ESM2 35M,r8,lr_esm_1e-5,lr_1e-3')
plt.plot(range(10, 110, 10), lora_rank_1e_3_5e_5_F1s, label='ESM2 35M,r8,lr_esm_5e-5,lr_1e-3')
plt.legend()
plt.title("F1")
plt.subplot(2, 2, 4)
plt.plot(range(10, 110, 10), lora_rank_1e_3_5e_4_AUCs, label='ESM2 35M,r8,lr_esm_5e-4,lr_1e-3')
plt.plot(range(10, 110, 10), lora_rank_1e_3_1e_4_AUCs, label='ESM2 35M,r8,lr_esm_1e-4,lr_1e-3')
plt.plot(range(10, 110, 10), lora_rank_1e_3_1e_5_AUCs, label='ESM2 35M,r8,lr_esm_1e-5,lr_1e-3')
plt.plot(range(10, 110, 10), lora_rank_1e_3_5e_5_AUCs, label='ESM2 35M,r8,lr_esm_5e-5,lr_1e-3')
plt.legend()
plt.title("AUC")
# Out:
# Text(0.5, 1.0, 'AUC')

# %%
import matplotlib.pyplot as plt
with open("smile.out") as f:
    smile = f.readlines()
smile_precisions = []
smile_recalls = []
smile_F1s = []
smile_AUCs = []
for line in smile:
    if line.startswith(">>> pre"):
        smile_precisions.append(float(line.split("precision: ")[1].split("|")[0]))
        smile_recalls.append(float(line.split("recall: ")[1].split("|")[0]))
        smile_F1s.append(float(line.split("F1: ")[1].split("|")[0]))
        smile_AUCs.append(float(line.split("AUC: ")[1]))

# %%
plt.figure(figsize=(10, 10))
plt.subplot(2, 2, 1)
plt.plot(range(50, 1000, 50), baseline_precisions, label='ESM2 35M, Attn 1')
plt.plot(range(50, 1000, 50), smile_precisions, label='ESM2 35M, Attn 1 + SMILE')
plt.legend()
plt.title("Precisions")
plt.subplot(2, 2, 2)
plt.plot(range(50, 1000, 50), baseline_recalls, label='ESM2 35M, Attn 1')
plt.plot(range(50, 1000, 50), smile_recalls, label='ESM2 35M, Attn 1 + SMILE')
plt.legend()
plt.title("Recalls")
plt.subplot(2, 2, 3)
plt.plot(range(50, 1000, 50), baseline_F1s, label='ESM2 35M, Attn 1')
plt.plot(range(50, 1000, 50), smile_F1s, label='ESM2 35M, Attn 1 + SMILE')
plt.legend()
plt.title("F1")
plt.subplot(2, 2, 4)
plt.plot(range(50, 1000, 50), baseline_AUCs, label='ESM2 35M, Attn 1')
plt.plot(range(50, 1000, 50), smile_AUCs, label='ESM2 35M, Attn 1 + SMILE')
plt.legend()
plt.title("AUC")
# Out:
# Text(0.5, 1.0, 'AUC')

# %%
import matplotlib.pyplot as plt
with open("smile_real.out") as f:
    smile = f.readlines()
smile_real_precisions = []
smile_real_recalls = []
smile_real_F1s = []
smile_real_AUCs = []
for line in smile:
    if line.startswith(">>> pre"):
        smile_real_precisions.append(float(line.split("precision: ")[1].split("|")[0]))
        smile_real_recalls.append(float(line.split("recall: ")[1].split("|")[0]))
        smile_real_F1s.append(float(line.split("F1: ")[1].split("|")[0]))
        smile_real_AUCs.append(float(line.split("AUC: ")[1]))

# %%
plt.figure(figsize=(10, 10))
plt.subplot(2, 2, 1)
plt.plot(range(50, 1000, 50), baseline_precisions, label='ESM2 35M, Attn 1')
plt.plot(range(10, 1000, 10), smile_real_precisions, label='ESM2 35M, Attn 1 + SMILE')
plt.legend()
plt.title("Precisions")
plt.subplot(2, 2, 2)
plt.plot(range(50, 1000, 50), baseline_recalls, label='ESM2 35M, Attn 1')
plt.plot(range(10, 1000, 10), smile_real_recalls, label='ESM2 35M, Attn 1 + SMILE')
plt.legend()
plt.title("Recalls")
plt.subplot(2, 2, 3)
plt.plot(range(50, 1000, 50), baseline_F1s, label='ESM2 35M, Attn 1')
plt.plot(range(10, 1000, 10), smile_real_F1s, label='ESM2 35M, Attn 1 + SMILE')
plt.legend()
plt.title("F1")
plt.subplot(2, 2, 4)
plt.plot(range(50, 1000, 50), baseline_AUCs, label='ESM2 35M, Attn 1')
plt.plot(range(10, 1000, 10), smile_real_AUCs, label='ESM2 35M, Attn 1 + SMILE')
plt.legend()
plt.title("AUC")
# Out:
# Text(0.5, 1.0, 'AUC')

# %%
import matplotlib.pyplot as plt
with open("baseline_more.out") as f:
    baseline_more = f.readlines()
baseline_more_precisions = []
baseline_more_recalls = []
baseline_more_F1s = []
baseline_more_AUCs = []
for line in baseline_more:
    if line.startswith(">>> pre"):
        baseline_more_precisions.append(float(line.split("precision: ")[1].split("|")[0]))
        baseline_more_recalls.append(float(line.split("recall: ")[1].split("|")[0]))
        baseline_more_F1s.append(float(line.split("F1: ")[1].split("|")[0]))
        baseline_more_AUCs.append(float(line.split("AUC: ")[1]))

# %%
import matplotlib.pyplot as plt
with open("random_aug.out") as f:
    random_aug = f.readlines()
random_aug_precisions = []
random_aug_recalls = []
random_aug_F1s = []
random_aug_AUCs = []
for line in random_aug:
    if line.startswith(">>> pre"):
        random_aug_precisions.append(float(line.split("precision: ")[1].split("|")[0]))
        random_aug_recalls.append(float(line.split("recall: ")[1].split("|")[0]))
        random_aug_F1s.append(float(line.split("F1: ")[1].split("|")[0]))
        random_aug_AUCs.append(float(line.split("AUC: ")[1]))

# %%
import matplotlib.pyplot as plt
with open("design_1_more.out") as f:
    design_1_more = f.readlines()
design_1_more_precisions = []
design_1_more_recalls = []
design_1_more_F1s = []
design_1_more_AUCs = []
for line in design_1_more:
    if line.startswith(">>> pre"):
        design_1_more_precisions.append(float(line.split("precision: ")[1].split("|")[0]))
        design_1_more_recalls.append(float(line.split("recall: ")[1].split("|")[0]))
        design_1_more_F1s.append(float(line.split("F1: ")[1].split("|")[0]))
        design_1_more_AUCs.append(float(line.split("AUC: ")[1]))

# %%
import matplotlib.pyplot as plt
with open("all.out") as f:
    random_aug = f.readlines()
random_aug_precisions = []
random_aug_recalls = []
random_aug_F1s = []
random_aug_AUCs = []
for line in random_aug:
    if line.startswith(">>> pre"):
        random_aug_precisions.append(float(line.split("precision: ")[1].split("|")[0]))
        random_aug_recalls.append(float(line.split("recall: ")[1].split("|")[0]))
        random_aug_F1s.append(float(line.split("F1: ")[1].split("|")[0]))
        random_aug_AUCs.append(float(line.split("AUC: ")[1]))

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
plt.subplot(2, 2, 1)
plt.plot(range(50, 1000, 50), baseline_more_precisions, label='ESM2 35M')
plt.plot(range(50, 1000, 50), design_1_more_precisions, label='ESM2 35M, Attn 1')
plt.plot(range(10, 1000, 10), random_aug_precisions, label='ESM2 35M, Attn 1 + SMILE + Random Aug')
plt.legend()
plt.title("Precisions")
plt.subplot(2, 2, 2)
plt.plot(range(50, 1000, 50), baseline_more_recalls, label='ESM2 35M')
plt.plot(range(50, 1000, 50), design_1_more_recalls, label='ESM2 35M, Attn 1')
plt.plot(range(10, 1000, 10), random_aug_recalls, label='ESM2 35M, Attn 1 + SMILE + Random Aug')
plt.legend()
plt.title("Recalls")
plt.subplot(2, 2, 3)
plt.plot(range(50, 1000, 50), baseline_more_F1s, label='ESM2 35M')
plt.plot(range(50, 1000, 50), design_1_more_F1s, label='ESM2 35M, Attn 1')
plt.plot(range(10, 1000, 10), random_aug_F1s, label='ESM2 35M, Attn 1 + SMILE + Random Aug')
plt.legend()
plt.title("F1")
plt.subplot(2, 2, 4)
plt.plot(range(50, 1000, 50), baseline_more_AUCs, label='ESM2 35M')
plt.plot(range(50, 1000, 50), design_1_more_AUCs, label='ESM2 35M, Attn 1')
plt.plot(range(10, 1000, 10), random_aug_AUCs, label='ESM2 35M, Attn 1 + SMILE + Random Aug')
plt.legend()
plt.title("AUC")
# Out:
# Text(0.5, 1.0, 'AUC')

# %%
import matplotlib.pyplot as plt
with open("negative_classification.out") as f:
    negative_classification = f.readlines()
negative_classification_precisions = []
negative_classification_recalls = []
negative_classification_F1s = []
negative_classification_AUCs = []
for line in negative_classification:
    if line.startswith(">>> pre"):
        negative_classification_precisions.append(float(line.split("precision: ")[1].split("|")[0]))
        negative_classification_recalls.append(float(line.split("recall: ")[1].split("|")[0]))
        negative_classification_F1s.append(float(line.split("F1: ")[1].split("|")[0]))
        negative_classification_AUCs.append(float(line.split("AUC: ")[1]))

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
plt.subplot(2, 2, 1)
plt.plot(range(50, 1000, 50), baseline_more_precisions, label='ESM2 35M')
plt.plot(range(50, 1000, 50), design_1_more_precisions, label='ESM2 35M, Attn 1')
plt.plot(range(10, 1000, 10), negative_classification_precisions, label='ESM2 35M, Attn 1 + SMILE + Neg')
plt.legend()
plt.title("Precisions")
plt.subplot(2, 2, 2)
plt.plot(range(50, 1000, 50), baseline_more_recalls, label='ESM2 35M')
plt.plot(range(50, 1000, 50), design_1_more_recalls, label='ESM2 35M, Attn 1')
plt.plot(range(10, 1000, 10), negative_classification_recalls, label='ESM2 35M, Attn 1 + SMILE + Neg')
plt.legend()
plt.title("Recalls")
plt.subplot(2, 2, 3)
plt.plot(range(50, 1000, 50), baseline_more_F1s, label='ESM2 35M')
plt.plot(range(50, 1000, 50), design_1_more_F1s, label='ESM2 35M, Attn 1')
plt.plot(range(10, 1000, 10), negative_classification_F1s, label='ESM2 35M, Attn 1 + SMILE + Neg')
plt.legend()
plt.title("F1")
plt.subplot(2, 2, 4)
plt.plot(range(50, 1000, 50), baseline_more_AUCs, label='ESM2 35M')
plt.plot(range(50, 1000, 50), design_1_more_AUCs, label='ESM2 35M, Attn 1')
plt.plot(range(10, 1000, 10), negative_classification_AUCs, label='ESM2 35M, Attn 1 + SMILE + Neg')
plt.legend()
plt.title("AUC")
# Out:
# Text(0.5, 1.0, 'AUC')

# %%
import matplotlib.pyplot as plt
with open("with_randaug_with_neg_pairs.out") as f:
    with_randaug_with_neg_pairs = f.readlines()
with_randaug_with_neg_pairs_precisions = []
with_randaug_with_neg_pairs_recalls = []
with_randaug_with_neg_pairs_F1s = []
with_randaug_with_neg_pairs_AUCs = []
for line in with_randaug_with_neg_pairs:
    if line.startswith(">>> pre"):
        with_randaug_with_neg_pairs_precisions.append(float(line.split("precision: ")[1].split("|")[0]))
        with_randaug_with_neg_pairs_recalls.append(float(line.split("recall: ")[1].split("|")[0]))
        with_randaug_with_neg_pairs_F1s.append(float(line.split("F1: ")[1].split("|")[0]))
        with_randaug_with_neg_pairs_AUCs.append(float(line.split("AUC: ")[1]))

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
plt.subplot(2, 2, 1)
plt.plot(range(50, 1000, 50), baseline_more_precisions, label='ESM2 35M')
plt.plot(range(50, 1000, 50), design_1_more_precisions, label='ESM2 35M, Attn 1')
plt.plot(range(10, 110, 10), with_randaug_with_neg_pairs_precisions[-10:], label='ESM2 35M, Attn 1 + SMILE + Random Aug + Neg + Lora')
plt.legend()
plt.title("Precisions")
plt.subplot(2, 2, 2)
plt.plot(range(50, 1000, 50), baseline_more_recalls, label='ESM2 35M')
plt.plot(range(50, 1000, 50), design_1_more_recalls, label='ESM2 35M, Attn 1')
plt.plot(range(10, 110, 10), with_randaug_with_neg_pairs_recalls[-10:], label='ESM2 35M, Attn 1 + SMILE + Random Aug + Neg + Lora')
plt.legend()
plt.title("Recalls")
plt.subplot(2, 2, 3)
plt.plot(range(50, 1000, 50), baseline_more_F1s, label='ESM2 35M')
plt.plot(range(50, 1000, 50), design_1_more_F1s, label='ESM2 35M, Attn 1')
plt.plot(range(10, 110, 10), with_randaug_with_neg_pairs_F1s[-10:], label='ESM2 35M, Attn 1 + SMILE + Random Aug + Neg + Lora')
plt.legend()
plt.title("F1")
plt.subplot(2, 2, 4)
plt.plot(range(50, 1000, 50), baseline_more_AUCs, label='ESM2 35M')
plt.plot(range(50, 1000, 50), design_1_more_AUCs, label='ESM2 35M, Attn 1')
plt.plot(range(10, 110, 10), with_randaug_with_neg_pairs_AUCs[-10:], label='ESM2 35M, Attn 1 + SMILE + Random Aug + Neg + Lora')
plt.legend()
plt.title("AUC")
# Out:
# Text(0.5, 1.0, 'AUC')

# %%
import matplotlib.pyplot as plt
with open("with_randaug_with_neg_pairs.out") as f:
    with_randaug_with_neg_pairs = f.readlines()
with_randaug_with_neg_pairs_precisions = []
with_randaug_with_neg_pairs_recalls = []
with_randaug_with_neg_pairs_F1s = []
with_randaug_with_neg_pairs_AUCs = []
for line in with_randaug_with_neg_pairs:
    if line.startswith(">>> pre"):
        with_randaug_with_neg_pairs_precisions.append(float(line.split("precision: ")[1].split("|")[0]))
        with_randaug_with_neg_pairs_recalls.append(float(line.split("recall: ")[1].split("|")[0]))
        with_randaug_with_neg_pairs_F1s.append(float(line.split("F1: ")[1].split("|")[0]))
        with_randaug_with_neg_pairs_AUCs.append(float(line.split("AUC: ")[1]))

# %%
import matplotlib.pyplot as plt
with open("without_randaug_with_neg_pairs.out") as f:
    without_randaug_with_neg_pairs = f.readlines()
without_randaug_with_neg_pairs_precisions = []
without_randaug_with_neg_pairs_recalls = []
without_randaug_with_neg_pairs_F1s = []
without_randaug_with_neg_pairs_AUCs = []
for line in without_randaug_with_neg_pairs:
    if line.startswith(">>> pre"):
        without_randaug_with_neg_pairs_precisions.append(float(line.split("precision: ")[1].split("|")[0]))
        without_randaug_with_neg_pairs_recalls.append(float(line.split("recall: ")[1].split("|")[0]))
        without_randaug_with_neg_pairs_F1s.append(float(line.split("F1: ")[1].split("|")[0]))
        without_randaug_with_neg_pairs_AUCs.append(float(line.split("AUC: ")[1]))

# %%
import matplotlib.pyplot as plt
with open("with_randaug_without_neg_pairs.out") as f:
    with_randaug_without_neg_pairs = f.readlines()
with_randaug_without_neg_pairs_precisions = []
with_randaug_without_neg_pairs_recalls = []
with_randaug_without_neg_pairs_F1s = []
with_randaug_without_neg_pairs_AUCs = []
for line in with_randaug_without_neg_pairs:
    if line.startswith(">>> pre"):
        with_randaug_without_neg_pairs_precisions.append(float(line.split("precision: ")[1].split("|")[0]))
        with_randaug_without_neg_pairs_recalls.append(float(line.split("recall: ")[1].split("|")[0]))
        with_randaug_without_neg_pairs_F1s.append(float(line.split("F1: ")[1].split("|")[0]))
        with_randaug_without_neg_pairs_AUCs.append(float(line.split("AUC: ")[1]))

# %%
import matplotlib.pyplot as plt
with open("without_randaug_without_neg_pairs.out") as f:
    without_randaug_without_neg_pairs = f.readlines()
without_randaug_without_neg_pairs_precisions = []
without_randaug_without_neg_pairs_recalls = []
without_randaug_without_neg_pairs_F1s = []
without_randaug_without_neg_pairs_AUCs = []
for line in without_randaug_without_neg_pairs:
    if line.startswith(">>> pre"):
        without_randaug_without_neg_pairs_precisions.append(float(line.split("precision: ")[1].split("|")[0]))
        without_randaug_without_neg_pairs_recalls.append(float(line.split("recall: ")[1].split("|")[0]))
        without_randaug_without_neg_pairs_F1s.append(float(line.split("F1: ")[1].split("|")[0]))
        without_randaug_without_neg_pairs_AUCs.append(float(line.split("AUC: ")[1]))

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
plt.subplot(2, 2, 1)
plt.plot(range(20, len(with_randaug_with_neg_pairs_F1s) * 20 + 20, 20), with_randaug_with_neg_pairs_precisions, label='ESM2 35M, Attn 1 + SMILE + Random Aug + Neg + LoRA')
plt.plot(range(20, len(without_randaug_with_neg_pairs_F1s) * 20 + 20, 20), without_randaug_with_neg_pairs_precisions, label='ESM2 35M, Attn 1 + SMILE + Neg + LoRA')
plt.plot(range(20, len(with_randaug_without_neg_pairs_F1s) * 20 + 20, 20), with_randaug_without_neg_pairs_precisions, label='ESM2 35M, Attn 1 + SMILE + Random Aug + LoRA')
plt.plot(range(20, len(without_randaug_without_neg_pairs_F1s) * 20 + 20, 20), without_randaug_without_neg_pairs_precisions, label='ESM2 35M, Attn 1 + SMILE + LoRA')


plt.legend()
plt.title("Precisions")
plt.subplot(2, 2, 2)
plt.plot(range(20, len(with_randaug_with_neg_pairs_F1s) * 20 + 20, 20), with_randaug_with_neg_pairs_recalls, label='ESM2 35M, Attn 1 + SMILE + Random Aug + Neg + LoRA')
plt.plot(range(20, len(without_randaug_with_neg_pairs_F1s) * 20 + 20, 20), without_randaug_with_neg_pairs_recalls, label='ESM2 35M, Attn 1 + SMILE + Neg + LoRA')
plt.plot(range(20, len(with_randaug_without_neg_pairs_F1s) * 20 + 20, 20), with_randaug_without_neg_pairs_recalls, label='ESM2 35M, Attn 1 + SMILE + Random Aug + LoRA')
plt.plot(range(20, len(without_randaug_without_neg_pairs_F1s) * 20 + 20, 20), without_randaug_without_neg_pairs_precisions, label='ESM2 35M, Attn 1 + SMILE + LoRA')


plt.legend()
plt.title("Recalls")
plt.subplot(2, 2, 3)
plt.plot(range(20, len(with_randaug_with_neg_pairs_F1s) * 20 + 20, 20), with_randaug_with_neg_pairs_F1s, label='ESM2 35M, Attn 1 + SMILE + Random Aug + Neg + LoRA')
plt.plot(range(20, len(without_randaug_with_neg_pairs_F1s) * 20 + 20, 20), without_randaug_with_neg_pairs_F1s, label='ESM2 35M, Attn 1 + SMILE + Neg + LoRA')
plt.plot(range(20, len(with_randaug_without_neg_pairs_F1s) * 20 + 20, 20), with_randaug_without_neg_pairs_F1s, label='ESM2 35M, Attn 1 + SMILE + Random Aug + LoRA')
plt.plot(range(20, len(without_randaug_without_neg_pairs_F1s) * 20 + 20, 20), without_randaug_without_neg_pairs_F1s, label='ESM2 35M, Attn 1 + SMILE + LoRA')


plt.legend()
plt.title("F1")
plt.subplot(2, 2, 4)
plt.plot(range(20, len(with_randaug_with_neg_pairs_AUCs) * 20 + 20, 20), with_randaug_with_neg_pairs_AUCs, label='ESM2 35M, Attn 1 + SMILE + Random Aug + Neg + LoRA')
plt.plot(range(20, len(without_randaug_with_neg_pairs_F1s) * 20 + 20, 20), without_randaug_with_neg_pairs_AUCs, label='ESM2 35M, Attn 1 + SMILE + Neg + LoRA')
plt.plot(range(20, len(with_randaug_without_neg_pairs_F1s) * 20 + 20, 20), with_randaug_without_neg_pairs_AUCs, label='ESM2 35M, Attn 1 + SMILE + Random Aug + LoRA')
plt.plot(range(20, len(without_randaug_without_neg_pairs_F1s) * 20 + 20, 20), without_randaug_without_neg_pairs_AUCs, label='ESM2 35M, Attn 1 + SMILE + LoRA')


plt.legend()
plt.title("AUC")
# Out:
# Text(0.5, 1.0, 'AUC')
